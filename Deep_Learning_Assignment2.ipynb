# %%
import numpy as np
import pandas as pd

np.random.seed(42)

sodium = np.random.uniform(12, 18, 6)
magnesium = np.random.uniform(1.5, 2.8, 6)
calcium = np.random.uniform(7, 11.5, 6)
ri = np.random.uniform(1.50, 1.55, 6)

df = pd.DataFrame({
    "Sodium": sodium,
    "Magnesium": magnesium,
    "Calcium": calcium,
    "Refractive_Index": ri
})

SODIUM_THRESHOLD = 15.5
CALCIUM_THRESHOLD = 10.0

df["Decision"] = np.where(
    (df["Sodium"] > SODIUM_THRESHOLD) | (df["Calcium"] > CALCIUM_THRESHOLD),
    "Reject",
    "Accept"
)

print(df)
# Out:
#       Sodium  Magnesium    Calcium  Refractive_Index Decision
# 0  14.247241   1.575509  10.745992          1.521597   Reject
# 1  17.704286   2.626029   7.955526          1.514561   Reject
# 2  16.391964   2.281450   7.818212          1.530593   Reject
# 3  15.591951   2.420494   7.825320          1.506975   Reject
# 4  12.936112   1.526760   8.369090          1.514607   Accept
# 5  12.935967   2.760883   9.361404          1.518318   Accept
